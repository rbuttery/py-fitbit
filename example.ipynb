# %%
from fitbit.client import FitbitClient

fitbit = FitbitClient()
fitbit.get_profile()
# Out:
# {'user': {'age': 31,
#   'ambassador': False,
#   'avatar': 'https://static0.fitbit.com/images/profile/defaultProfile_100.png',
#   'avatar150': 'https://static0.fitbit.com/images/profile/defaultProfile_150.png',
#   'avatar640': 'https://static0.fitbit.com/images/profile/defaultProfile_640.png',
#   'averageDailySteps': 3359,
#   'challengesBeta': True,
#   'clockTimeDisplayFormat': '12hour',
#   'corporate': False,
#   'corporateAdmin': False,
#   'dateOfBirth': '1993-01-14',
#   'displayName': 'Robert B.',
#   'displayNameSetting': 'name',
#   'distanceUnit': 'METRIC',
#   'encodedId': 'BY8CQZ',
#   'features': {'exerciseGoal': True},
#   'firstName': 'Robert',
#   'foodsLocale': 'en_GB',
#   'fullName': 'Robert Buttery',
#   'gender': 'MALE',
#   'glucoseUnit': 'METRIC',
#   'height': 189.0,
#   'heightUnit': 'METRIC',
#   'isBugReportEnabled': False,
#   'isChild': False,
#   'isCoach': False,
#   'languageLocale': 'en_GB',
#   'lastName': 'Buttery',
# ...

# %%
import pandas as pd
pd.DataFrame(fitbit.get_heart_rate_intraday_by_date(date=fitbit.Dates.TODAY)['activities-heart'])
# Out:
# [{'value': {'customHeartRateZones': [],
#    'heartRateZones': [{'caloriesOut': 1997.15906,
#      'max': 118,
#      'min': 30,
#      'minutes': 1412,
#      'name': 'Out of Range'},
#     {'caloriesOut': 116.56271999999998,
#      'max': 141,
#      'min': 118,
#      'minutes': 15,
#      'name': 'Fat Burn'},
#     {'caloriesOut': 161.67965,
#      'max': 171,
#      'min': 141,
#      'minutes': 13,
#      'name': 'Cardio'},
#     {'caloriesOut': 0, 'max': 220, 'min': 171, 'minutes': 0, 'name': 'Peak'}],
#    'restingHeartRate': 71},
#   'dateTime': '2024-11-05'}]
