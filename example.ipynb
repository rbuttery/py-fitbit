# %%
import os
from dotenv import load_dotenv
from fitbit.auth import FitbitOauth2Client

load_dotenv()

client_id = os.getenv('FITBIT_CLIENT_ID')
client_secret = os.getenv('FITBIT_CLIENT_SECRET')

client = FitbitOauth2Client(client_id, client_secret)
client.get_local_tokens()
# Out:
# token.json not found
# [05/Nov/2024:18:09:11] ENGINE Listening for SIGTERM.
# [05/Nov/2024:18:09:11] ENGINE Bus STARTING
# [05/Nov/2024:18:09:11] ENGINE Set handler for console events.
# CherryPy Checker:
# The Application mounted at '' has an empty config.
#
# [05/Nov/2024:18:09:11] ENGINE Started monitor thread 'Autoreloader'.
# [05/Nov/2024:18:09:12] ENGINE Serving on http://127.0.0.1:8080
# [05/Nov/2024:18:09:12] ENGINE Bus STARTED
# 127.0.0.1 - - [05/Nov/2024:18:09:13] "GET /?code=e28b65fe1d5b4bf224008f4409bce8d66d41dcfd&state=qx5x1dKNkjAN8TmmWDnZAgaJlCG1sz HTTP/1.1" 200 436 "" "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36"
# [05/Nov/2024:18:09:14] ENGINE Bus STOPPING
# [05/Nov/2024:18:09:14] ENGINE HTTP Server cherrypy._cpwsgi_server.CPWSGIServer(('127.0.0.1', 8080)) shut down
# [05/Nov/2024:18:09:14] ENGINE Removed handler for console events.
# [05/Nov/2024:18:09:14] ENGINE Stopped thread 'Autoreloader'.
# [05/Nov/2024:18:09:14] ENGINE Bus STOPPED
# [05/Nov/2024:18:09:14] ENGINE Bus EXITING
# [05/Nov/2024:18:09:14] ENGINE Waiting for child threads to terminate...
# [05/Nov/2024:18:09:14] ENGINE Bus EXITED
# [05/Nov/2024:18:09:14] ENGINE Waiting for thread Thread-16.
